# %%
import pandas as pd 

df = pd.read_csv("../data/salaries.csv", index_col = 0,parse_dates=True)
df.head()
# Out:
#            experience_level employment_type       job_title  salary  \
# work_year
# 2025-01-01               EX              FT    Head of Data  348516
# 2025-01-01               EX              FT    Head of Data  232344
# 2025-01-01               SE              FT  Data Scientist  145400
# 2025-01-01               SE              FT  Data Scientist   81600
# 2025-01-01               MI              FT        Engineer  160000
#
#            salary_currency  salary_in_usd employee_residence  remote_ratio  \
# work_year
# 2025-01-01             USD         348516                 US             0
# 2025-01-01             USD         232344                 US             0
# 2025-01-01             USD         145400                 US             0
# 2025-01-01             USD          81600                 US             0
# 2025-01-01             USD         160000                 US           100
#
#            company_location company_size
# work_year
# 2025-01-01               US            M
# 2025-01-01               US            M
# 2025-01-01               US            M
# 2025-01-01               US            M
# 2025-01-01               US            M

# %%
print("Columns:", df.columns.tolist())
print("Shape:", df.shape)
print("\nData types and non-null counts:")
print(df.info())
print("\nDescriptive statistics (numeric columns):")
print(df.describe())
# Out:
# Columns: ['experience_level', 'employment_type', 'job_title', 'salary', 'salary_currency', 'salary_in_usd', 'employee_residence', 'remote_ratio', 'company_location', 'company_size']
# Shape: (151445, 10)
#
# Data types and non-null counts:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 151445 entries, 2025-01-01 to 2021-01-01
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   experience_level    151445 non-null  object
#  1   employment_type     151445 non-null  object
#  2   job_title           151445 non-null  object
#  3   salary              151445 non-null  int64
#  4   salary_currency     151445 non-null  object
#  5   salary_in_usd       151445 non-null  int64
#  6   employee_residence  151445 non-null  object
#  7   remote_ratio        151445 non-null  int64
#  8   company_location    151445 non-null  object
#  9   company_size        151445 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 12.7+ MB
# None
#
# Descriptive statistics (numeric columns):
#              salary  salary_in_usd   remote_ratio
# count  1.514450e+05  151445.000000  151445.000000
# mean   1.628380e+05  157527.458411      20.938625
# std    2.080124e+05   74150.772377      40.620393
# min    1.400000e+04   15000.000000       0.000000
# 25%    1.060000e+05  105800.000000       0.000000
# 50%    1.470000e+05  146100.000000       0.000000
# 75%    1.990000e+05  198000.000000       0.000000
# max    3.040000e+07  800000.000000     100.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.histplot(df['salary_in_usd'], bins=30, kde=True)
plt.title("Distribution of Salaries in USD")
plt.xlabel("Salary (USD)")
plt.ylabel("Count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
#       4 plt.figure(figsize=(12, 6))
#
# File c:\Users\alans\Documents\GitHub\ai_engineering_malik_alansi\.venv\Lib\site-packages\matplotlib\__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib._api import MatplotlibDeprecationWarning
#     163 from matplotlib.rcsetup import cycler  # noqa: F401
#
# ImportError: cannot import name '_version' from partially initialized module 'matplotlib' (most likely due to a circular import) (c:\Users\alans\Documents\GitHub\ai_engineering_malik_alansi\.venv\Lib\site-packages\matplotlib\__init__.py)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
